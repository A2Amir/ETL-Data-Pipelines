# %% [markdown]
# # Using APIs with Python
#
# If you wanted to pull data directly from the World Bank’s server, you’d have to know what database system the World Bank was using. You’d also need permission to log in directly to the server, which would be a security risk for the World Bank. And if the World Bank ever migrated its data to a new system, you would have to rewrite all of your code again. The API allows you to execute code on the World Bank server without getting direct access.
#
#
# Here are links to information about the World Bank indicators and projects APIs if you want to learn more:
# * [World Bank Indicators API](world bank projects api)
# * [World Bank Projects API](http://search.worldbank.org/api/v2/projects)

# %%
import requests
r = requests.get('http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD')
r.text
# Out:
# '\ufeff<?xml version="1.0" encoding="utf-8"?>\r\n<wb:data page="1" pages="2" per_page="50" total="60" sourceid="2" lastupdated="2020-05-28" xmlns:wb="http://www.worldbank.org">\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2019</wb:date>\r\n    <wb:value />\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2018</wb:date>\r\n    <wb:value>1885482534238.33</wb:value>\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2017</wb:date>\r\n    <wb:value>2062831045935.95</wb:value>\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2016</wb:date>\r\n    <wb:value>1795700168991.49</wb:value>\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2015</wb:date>\r\n    <wb:value>1802214373741.32</wb:value>\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2014</wb:date>\r\n    <wb:value>2455993625159.37</wb:value>\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2013</wb:date>\r\n    <wb:value>2472806919901.67</wb:value>\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2012</wb:date>\r\n    <wb:value>2465188674415.03</wb:value>\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2011</wb:date>\r\n    <wb:value>2616200980392.16</wb:value>\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2010</wb:date>\r\n    <wb:value>2208871646202.82</wb:value>\r\n    <wb:unit />\r\n    <wb:obs_status />\r\n    <wb:decimal>0</wb:decimal>\r\n  </wb:data>\r\n  <wb:data>\r\n    <wb:indicator id="NY.GDP.MKTP.CD">GDP (current US$)</wb:indicator>\r\n    <wb:country id="BR">Brazil</wb:country>\r\n    <wb:countryiso3code>BRA</wb:countryiso3code>\r\n    <wb:date>2009</wb:date>\r\n    <wb:value>1667019783585.08</wb:value>\r\n  ...

# %% [markdown]
# # Explanation of Results
#
# ```
# import requests
# ```
#
# This line imports the requests library.
#
# ```
# r = requests.get('http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD')
# ```
#
# The line `requests.get` sends out a "get" request to the url specified in parenthesis. The html standard specifies different types of [request methods](https://developer.mozilla.org/en-US/docs/Web/HTTP/Methods) with the most common one being "get". A "get" request is generally reserved for obtaining data from a server. For the World Bank API, you'll only need to make "get" requests. An API's documentation will generally tell you what type of requests to make.
#
# The last line of code outputs the results.
# ```
# r.text
# ```
#
# In this case, the output is xml data. [XML](https://www.w3schools.com/xml/xml_whatis.asp) is a language for storing and transmitting data. XML was standardized in the late 1990s. A few years later, the JSON format came along and serves a similar purpose. JSON tends to be much easier to work with and luckily, the World Bank API can return data in json format by specifying the format parameters.
#
# Next, you'll see how to send parameters with your get request.

# %% [markdown]
# # Sending Parameters with the Get Request
#
# This url, `http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD`, obtains GDP data for Brazil. You specify the country name with the [2-character ISO code](http://www.nationsonline.org/oneworld/country_code_list.htm) and then specify the economic indicator that you want, which in this case is `NY.GDP.MKTP.CD`.
#
# To see all of the possible indicators, visit the [world bank indicator dashboard](https://data.worldbank.org/indicator?tab=all) or use the API address `http://api.worldbank.org/v2/indicators`.
#
# The url syntax is specific to the World Bank API. Other APIs might be different.
#
# When making a get request, you can add parameters to the end of the url with the following syntax:
# `http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD?format=json&per_page=500&date=1990:2015`
#
# where a question mark was added at the end of the url following by each parameter name and parameter values. The parameters are separated by the ampersand & sign. Adding parameters to a get request with the question mark ? and ampersand is the standard way for adding parameters to a get request.
#
# With the requests library, you can send this get request in one of two ways. The first way specifies the entire url in a single string.
#
# ```
# r = requests.get('http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD?format=json&per_page=500&date=1990:2015')
#
# ```
#
# The second way separate the base url and the parameters.
#
# ```
# payload = {'format': 'json', 'per_page': '500', 'date':'1990:2015'}
# r = requests.get('http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD', params=payload)
# ```
#
# Why use the second version? It's somewhat easier to write programs with the second version because you can easily change the values in the payload dictionary whereas the first version involves manipulating the url string.
#
# Run the code cell below to show that both versions give the same results.

# %%
r_url = requests.get('http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD?format=json&per_page=500&date=1990:2015')

payload = {'format': 'json', 'per_page': '500', 'date':'1990:2015'}
r_payload = requests.get('http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD', params=payload)

# Test if both results are the same string
r_url.text == r_payload.text
# Out:
# True

# %% [markdown]
# # Navigating the JSON response
#
# Once you have the data, what can you do with it? The requests library comes with a json decoder. In order to obtain the json response, all you have to do is use the .json() method like so:
#
# ```
# payload = {'format': 'json', 'per_page': '500', 'date':'1990:2015'}
# r = requests.get('http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD', params=payload)
# r.json()
# ```
#
# Run the cell below to see the results:

# %%
payload = {'format': 'json', 'per_page': '500', 'date':'1990:2020'}
r = requests.get('http://api.worldbank.org/v2/countries/br/indicators/NY.GDP.MKTP.CD', params=payload)
r.json()
# Out:
# [{'lastupdated': '2020-05-28',
#   'page': 1,
#   'pages': 1,
#   'per_page': 500,
#   'sourceid': '32',
#   'total': 30},
#  [{'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2019',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': None},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2018',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 1885482534238.33},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2017',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 2062831045935.95},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2016',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 1795700168991.49},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2015',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 1802214373741.32},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2014',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 2455993625159.37},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2013',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 2472806919901.67},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2012',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 2465188674415.03},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2011',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 2616200980392.16},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2010',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 2208871646202.82},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2009',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 1667019783585.08},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2008',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 1695824565983.2},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2007',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 1397084349956.35},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2006',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 1107640289615.23},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2005',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 891630177251.068},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2004',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 669316654017.094},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2003',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 558319920831.979},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2002',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 507962487700.024},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2001',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 559372276081.966},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '2000',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 655420645476.906},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1999',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 599388579985.673},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1998',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 863723411632.917},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1997',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 883199625324.675},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1996',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 850426432991.742},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1995',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 769305386182.849},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1994',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 558111997497.263},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1993',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 437798577639.752},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1992',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 400599250000},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1991',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 602860000000},
#   {'country': {'id': 'BR', 'value': 'Brazil'},
#    'countryiso3code': 'BRA',
#    'date': '1990',
#    'decimal': 0,
#    'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'obs_status': '',
#    'unit': '',
#    'value': 461951782000}]]

# %% [markdown]
# The result is a list of json values, which you can iterate through to access all of the data. Every API will return data in a slightly different way, so you need to look at the data and figure out how to clean the data for your purposes. For example, in the json response, the first entry contains meta data about the results. The second entry is a list containing all of the data points. For the purposes of analyzing the data, you only need the second entry, which you can access with `r.json()[1]`.
#
#
# By opening this data in a pandas data frame,we would need some cleaning to be used. That would happen later in the transformation step of an ETL pipeline but we can run iterate through the data, clean the data, and then plot the results.

# %%
import pandas as pd
pd.DataFrame(r.json()[1]).head()
# Out:
#                            country countryiso3code  date  decimal  \
# 0  {'id': 'BR', 'value': 'Brazil'}             BRA  2019        0
# 1  {'id': 'BR', 'value': 'Brazil'}             BRA  2018        0
# 2  {'id': 'BR', 'value': 'Brazil'}             BRA  2017        0
# 3  {'id': 'BR', 'value': 'Brazil'}             BRA  2016        0
# 4  {'id': 'BR', 'value': 'Brazil'}             BRA  2015        0
#
#                                            indicator obs_status unit  \
# 0  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 1  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 4  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#           value
# 0           NaN
# 1  1.885483e+12
# 2  2.062831e+12
# 3  1.795700e+12
# 4  1.802214e+12

# %%
for entry in r.json()[1]:
    print(entry)
    print(entry['country']['value'])
    print(entry['value'])
# Out:
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2019', 'value': None, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# None
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2018', 'value': 1885482534238.33, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 1885482534238.33
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2017', 'value': 2062831045935.95, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 2062831045935.95
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2016', 'value': 1795700168991.49, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 1795700168991.49
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2015', 'value': 1802214373741.32, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 1802214373741.32
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2014', 'value': 2455993625159.37, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 2455993625159.37
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2013', 'value': 2472806919901.67, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 2472806919901.67
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2012', 'value': 2465188674415.03, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 2465188674415.03
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2011', 'value': 2616200980392.16, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 2616200980392.16
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2010', 'value': 2208871646202.82, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 2208871646202.82
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2009', 'value': 1667019783585.08, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 1667019783585.08
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2008', 'value': 1695824565983.2, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 1695824565983.2
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2007', 'value': 1397084349956.35, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 1397084349956.35
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2006', 'value': 1107640289615.23, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 1107640289615.23
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2005', 'value': 891630177251.068, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 891630177251.068
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2004', 'value': 669316654017.094, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 669316654017.094
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2003', 'value': 558319920831.979, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 558319920831.979
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2002', 'value': 507962487700.024, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 507962487700.024
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2001', 'value': 559372276081.966, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 559372276081.966
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '2000', 'value': 655420645476.906, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 655420645476.906
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1999', 'value': 599388579985.673, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 599388579985.673
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1998', 'value': 863723411632.917, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 863723411632.917
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1997', 'value': 883199625324.675, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 883199625324.675
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1996', 'value': 850426432991.742, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 850426432991.742
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1995', 'value': 769305386182.849, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 769305386182.849
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1994', 'value': 558111997497.263, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 558111997497.263
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1993', 'value': 437798577639.752, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 437798577639.752
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1992', 'value': 400599250000, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 400599250000
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1991', 'value': 602860000000, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 602860000000
# {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'}, 'country': {'id': 'BR', 'value': 'Brazil'}, 'countryiso3code': 'BRA', 'date': '1990', 'value': 461951782000, 'unit': '', 'obs_status': '', 'decimal': 0}
# Brazil
# 461951782000

# %%
# get the World Bank GDP data for Brazil, China and the United States
payload = {'format': 'json', 'per_page': '500', 'date':'1990:2019'}
r = requests.get('http://api.worldbank.org/v2/countries/br;cn;ir;us/indicators/NY.GDP.MKTP.CD', params=payload)

# put the results in a dictionary where each country contains a list of all the x values and all the y values
# this will make it easier to plot the results
from collections import defaultdict
data = defaultdict(list)

for entry in r.json()[1]:
     # check if country is already in dictionary. If so, append the new x and y values to the lists
    if data[entry['country']['value']]:
        data[entry['country']['value']][0].append(int(entry['date']))
        data[entry['country']['value']][1].append(entry['value'])
    else: # if country not in dictionary, then initialize the lists that will hold the x and y values
        data[entry['country']['value']]=[[],[]]


# show the results contained in the data dictionary
for country in data:
    print(country)
    print(data[country][0])
    print(data[country][1])
    print('\n')
# Out:
# Brazil
# [2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990]
# [1885482534238.33, 2062831045935.95, 1795700168991.49, 1802214373741.32, 2455993625159.37, 2472806919901.67, 2465188674415.03, 2616200980392.16, 2208871646202.82, 1667019783585.08, 1695824565983.2, 1397084349956.35, 1107640289615.23, 891630177251.068, 669316654017.094, 558319920831.979, 507962487700.024, 559372276081.966, 655420645476.906, 599388579985.673, 863723411632.917, 883199625324.675, 850426432991.742, 769305386182.849, 558111997497.263, 437798577639.752, 400599250000, 602860000000, 461951782000]
#
#
# China
# [2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990]
# [13608151864637.9, 12143491448186.1, 11137945669350.6, 11015542352468.9, 10438529153237.6, 9570405758739.79, 8532230724141.76, 7551500425597.77, 6087164527421.24, 5101702432883.45, 4594306848763.08, 3550342425238.25, 2752131773355.16, 2285965892360.54, 1955347004963.27, 1660287965662.68, 1470550015081.55, 1339395718865.3, 1211346869605.24, 1093997267271.06, 1029043097554.08, 961603952951.82, 863746717503.789, 734547898220.508, 564324670005.917, 444731282436.762, 426915712711.146, 383373318083.624, 360857912565.966]
#
#
# Iran, Islamic Rep.
# [2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990]
# [None, 454012768723.589, 418976679728.567, 385874474398.59, 434474616831.914, 467414852231.299, 598853401276.101, 583500357530.414, 487069570463.768, 414059094949.063, 406070949553.875, 349881601458.56, 266298911661.144, 226452138291.542, 190043433964.841, 153544751395.43, 128626917503.72, 126878750295.962, 109591707802.233, 113848450088.351, 110276913362.539, 113919163421.119, 120403931885.441, 96419225743.6248, 71841461172.545, 63743623232.012, None, None, 124813263926.246]
#
#
# United States
# [2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990]
# [20544343456936.5, 19485393853000, 18707188235000, 18219297584000, 17521746534000, 16784849190000, 16197007349000, 15542581104000, 14992052727000, 14448933025000, 14712844084000, 14451858650000, 13814611414000, 13036640229000, 12213729147000, 11458243878000, 10936419054000, 10581821399000, 10252345464000, 9630664202000, 9062818211000, 8577554463000, 8073122000000, 7639749000000, 7287236000000, 6858559000000, 6520327000000, 6158129000000, 5963144000000]

# %%
# visualize the results with matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 

# create a plot for each country
for country in data:
    plt.plot(data[country][0], data[country][1], label=country)

# label the plot
plt.title('GDP for Brazil, China,Iran ,and USA1990 to 2015')
plt.legend()
plt.xlabel('year')
plt.ylabel('GDP')
plt.show()

# %% [markdown]
# # Authentication
#
# The World Bank API does not require authentication; however, many API do require some sort of user authentication with a username and password that you need to send along with your request. The requests documentation gives the [basics of how to use authentication](http://docs.python-requests.org/en/master/user/authentication/) when sending a request.
#
# The Twitter API, for example, requires you to set up credentials.
# But before you get bogged down by the Twitter API documentation and authentication protocols, you might want to do an internet search for Python twitter libraries. Oftentimes, for the APIs of the big internet companies, someone has [built a library](https://developer.twitter.com/en/docs/developer-utilities/twitter-libraries.html) that makes it much easier to use the API.

# %% [markdown]
# # APIs

# %% [markdown]
# * [World Bank API](https://datahelpdesk.worldbank.org/knowledgebase/articles/889386-developer-information-overview)
# * [API for Entertainment Industry Data](http://developer.rovicorp.com/docs)
# * [City of Berlin Open Data API](https://daten.berlin.de/datensaetze/deutsche-digitale-bibliothek-ddb-api)
# * [APIs for pulling data about DVDs,movies,books,games](http://developer.rovicorp.com/docs)
#
# * [the Twitter API](https://developer.twitter.com/en/docs.html)
# * [the Google Maps API](https://cloud.google.com/maps-platform/)
# * [the Facebook Graph API](https://developers.facebook.com/docs/graph-api)
# * [the US Government Data API](https://www.data.gov/developers/apis).
# * [Facebook Graph API example](https://github.com/mobolic/facebook-sdk)
